# %%
from pandas import DataFrame
from urllib.parse import urlencode
from jsonapi_client import Session, Filter
import html

# %%
API_BASE = 'https://www.ebi.ac.uk/metagenomics/api/latest/'

# %%
def get_metadata(metadata, key):
    for m in metadata:
        if m['key'].lower() == key.lower():
            value = m['value']
            unit = html.unescape(m['unit']) if m['unit'] else ""
            return "{value} {unit}".format(value=value, unit=unit)
    return None

# %%
df = DataFrame(columns=('sample accession',
                        'sample name', 
                        'lineage', 
                        'biome',  
                        'material', 
                        'latitude', 
                        'longitude', 
                        'depth', 
                        'collection-date'))
                        #'fastq file link'))
df.index.name = 'run_id'

depth_label = 'geographic location (depth)'
#temp_label = 'temperature'

with Session(API_BASE) as s:
    params = {
        'experiment_type': 'metagenomic',
        'lineage': 'root:Environmental:Terrestrial'
    }
    fltr = Filter(urlencode(params))
    for run in s.iterate('runs', fltr):
        try:
            sample = s.get('samples', run.sample.id).resource
            df.loc[run.id] = [
                sample.accession,
                sample.sample_name,
                sample.biome.id,
                sample.environment_biome,
                sample.environment_material,
                sample.latitude,
                sample.longitude,
                get_metadata(sample.sample_metadata, depth_label),
                sample.collection_date 
            ]
        except Exception:
            continue

df
# Out:
# SRR1570802
# SRR1570801
# SRR1570772
# SRR1570769
# SRR1570765
# SRR1569898
# SRR1569894
# SRR1569871
# SRR1569812
# SRR1569742
# SRR1569470
# SRR1569466
# SRR1569462
# SRR1566021
# SRR1505375
# SRR1505370
# SRR1505369
# SRR1505362
# SRR1460491
# SRR1367218
# SRR1269557
# SRR1269555
# SRR1269554
# SRR1269498
# SRR1258098
# SRR1258097
# SRR1258096
# SRR1258095
# SRR1258094
# SRR1252000
# SRR1251999
# SRR1251997
# SRR1251996
# SRR1251995
# SRR1246239
# SRR1246238
# SRR1246237
# SRR1246236
# SRR1245949
# SRR1238387
# SRR1238386
# SRR1238385
# SRR1238384
# SRR1238383
# SRR1238382
# SRR1238381
# SRR1238380
# SRR1238379
# SRR1238378
# SRR1238377
# SRR1238376
# SRR1238375
# SRR1238374
# SRR1238373
# SRR1238372
# SRR1238371
# SRR1238370
# SRR1238369
# SRR1238368
# SRR1238367
# SRR1238366
# SRR1238365
# SRR1238364
# SRR1238363
# SRR1238362
# SRR1238361
# SRR1238360
# SRR1238359
# SRR1238358
# SRR1238357
# SRR1238356
# SRR1238355
# SRR1238354
# SRR1238353
# SRR1238352
# SRR1238350
# SRR1238349
# SRR1238348
# SRR1238347
# SRR1238346
# SRR1238345
# SRR1238344
# SRR1238343
# SRR1238342
# SRR1238341
# SRR1238340
# SRR1238339
# SRR1238338
# SRR1238337
# SRR1238336
# SRR1238335
# SRR1238334
# SRR1238333
# SRR1238332
# SRR1238331
# SRR1238330
# SRR1238329
# SRR1238328
# SRR1238327
# SRR1238326
# SRR1238325
# SRR1238324
# SRR1238323
# SRR1238322
# SRR1238321
# SRR1238320
# SRR1238319
# SRR1238318
# SRR1238317
# SRR1238316
# SRR1238315
# SRR1238314
# SRR1238313
# SRR1238312
# SRR1238311
#     124             next_doc = self.links.next.fetch()
# --> 125             yield from next_doc.iterator()
#     126
#     127     async def _iterator_async(self) -> 'AsyncIterator[ResourceObject]':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\document.py in _iterator_sync(self)
#     123         if self.links.next:
#     124             next_doc = self.links.next.fetch()
# --> 125             yield from next_doc.iterator()
#     126
#     127     async def _iterator_async(self) -> 'AsyncIterator[ResourceObject]':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\document.py in _iterator_sync(self)
#     123         if self.links.next:
#     124             next_doc = self.links.next.fetch()
# --> 125             yield from next_doc.iterator()
#     126
#     127     async def _iterator_async(self) -> 'AsyncIterator[ResourceObject]':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\document.py in _iterator_sync(self)
#     123         if self.links.next:
#     124             next_doc = self.links.next.fetch()
# --> 125             yield from next_doc.iterator()
#     126
#     127     async def _iterator_async(self) -> 'AsyncIterator[ResourceObject]':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\document.py in _iterator_sync(self)
#     123         if self.links.next:
#     124             next_doc = self.links.next.fetch()
# --> 125             yield from next_doc.iterator()
#     126
#     127     async def _iterator_async(self) -> 'AsyncIterator[ResourceObject]':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\document.py in _iterator_sync(self)
#     123         if self.links.next:
#     124             next_doc = self.links.next.fetch()
# --> 125             yield from next_doc.iterator()
#     126
#     127     async def _iterator_async(self) -> 'AsyncIterator[ResourceObject]':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\document.py in _iterator_sync(self)
#     123         if self.links.next:
#     124             next_doc = self.links.next.fetch()
# --> 125             yield from next_doc.iterator()
#     126
#     127     async def _iterator_async(self) -> 'AsyncIterator[ResourceObject]':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\document.py in _iterator_sync(self)
#     123         if self.links.next:
#     124             next_doc = self.links.next.fetch()
# --> 125             yield from next_doc.iterator()
#     126
#     127     async def _iterator_async(self) -> 'AsyncIterator[ResourceObject]':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\document.py in _iterator_sync(self)
#     122
#     123         if self.links.next:
# --> 124             next_doc = self.links.next.fetch()
#     125             yield from next_doc.iterator()
#     126
#
# C:\Anaconda\lib\site-packages\jsonapi_client\objects.py in fetch(self)
#     105             return self.fetch_async()
#     106         else:
# --> 107             return self.fetch_sync()
#     108
#     109     async def fetch_async(self) -> 'Optional[Document]':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\objects.py in fetch_sync(self)
#      99         self.session.assert_sync()
#     100         if self:
# --> 101             return self.session.fetch_document_by_url(self.url)
#     102
#     103     def fetch(self):
#
# C:\Anaconda\lib\site-packages\jsonapi_client\session.py in fetch_document_by_url(self, url)
#     455
#     456         # TODO: should we try to guess type, id from url?
# --> 457         return self.documents_by_link.get(url) or self._ext_fetch_by_url(url)
#     458
#     459     async def fetch_document_by_url_async(self, url: str) -> 'Document':
#
# C:\Anaconda\lib\site-packages\jsonapi_client\session.py in _ext_fetch_by_url(self, url)
#     469
#     470     def _ext_fetch_by_url(self, url: str) -> 'Document':
# --> 471         json_data = self._fetch_json(url)
#     472         return self.read(json_data, url)
#     473
#
# C:\Anaconda\lib\site-packages\jsonapi_client\session.py in _fetch_json(self, url)
#     486         parsed_url = urlparse(url)
#     487         logger.info('Fetching document from url %s', parsed_url)
# --> 488         response = requests.get(parsed_url.geturl(), **self._request_kwargs)
#     489         response_content = response.json()
#     490         if response.status_code == HttpStatus.OK_200:
#
# C:\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# C:\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# C:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# C:\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# C:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\Anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# C:\Anaconda\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# C:\Anaconda\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# C:\Anaconda\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# C:\Anaconda\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# C:\Anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# C:\Anaconda\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
#            sample accession  \
# run_id
# SRR992678         SRS481988
# SRR988097         SRS481050
# SRR988096         SRS481052
# SRR988095         SRS481051
# SRR988094         SRS481054
# ...                     ...
# SRR1505375        SRS652197
# SRR1505370        SRS652193
# SRR1505369        SRS652190
# SRR1505362        SRS652195
# SRR1460491        SRS646104
#
#                                                   sample name  \
# run_id
# SRR992678   Environmental/Metagenome sample for positive e...
# SRR988097   MIMS Environmental/Metagenome sample from envi...
# SRR988096   MIMS Environmental/Metagenome sample from envi...
# SRR988095   MIMS Environmental/Metagenome sample from envi...
# SRR988094   MIMS Environmental/Metagenome sample from envi...
# ...                                                       ...
# SRR1505375  MIMS Environmental/Metagenome sample from soil...
# SRR1505370  MIMS Environmental/Metagenome sample from soil...
# SRR1505369  MIMS Environmental/Metagenome sample from soil...
# SRR1505362  MIMS Environmental/Metagenome sample from soil...
# SRR1460491  MIMS Environmental/Metagenome sample from soil...
#
#                                                      lineage biome material  \
# run_id
# SRR992678                root:Environmental:Terrestrial:Soil  None     None
# SRR988097                root:Environmental:Terrestrial:Soil  None     None
# SRR988096                root:Environmental:Terrestrial:Soil  None     None
# SRR988095                root:Environmental:Terrestrial:Soil  None     None
# SRR988094                root:Environmental:Terrestrial:Soil  None     None
# ...                                                      ...   ...      ...
# SRR1505375  root:Environmental:Terrestrial:Soil:Contaminated  None     None
# SRR1505370  root:Environmental:Terrestrial:Soil:Contaminated  None     None
# SRR1505369  root:Environmental:Terrestrial:Soil:Contaminated  None     None
# SRR1505362  root:Environmental:Terrestrial:Soil:Contaminated  None     None
# SRR1460491  root:Environmental:Terrestrial:Soil:Agricultural  None     None
#
#             latitude  longitude    depth collection-date
# run_id
# SRR992678        NaN        NaN       0             None
# SRR988097        NaN        NaN  0-15cm             None
# SRR988096        NaN        NaN  0-15cm             None
# SRR988095        NaN        NaN  0-15cm             None
# SRR988094        NaN        NaN  0-15cm             None
# ...              ...        ...      ...             ...
# SRR1505375       NaN        NaN  1-5 cm             None
# SRR1505370       NaN        NaN  1-5 cm             None
# SRR1505369       NaN        NaN  1-5 cm             None
# SRR1505362       NaN        NaN  1-5 cm             None
# SRR1460491       NaN        NaN   20 cm             None
#
# [269 rows x 9 columns]
