# %%
from pandas import DataFrame, read_csv
from urllib.parse import urlencode
from jsonapi_client import Session, Filter
import html
import requests
import json

# %%
MGNIFY_API_BASE = 'https://www.ebi.ac.uk/metagenomics/api/latest/'
ena_url = 'https://www.ebi.ac.uk/ena/portal/api/filereport'

# %%
def get_metadata(metadata, key):
    for m in metadata:
        if m['key'].lower() == key.lower():
            value = m['value']
            unit = html.unescape(m['unit']) if m['unit'] else ""
            return "{value} {unit}".format(value=value, unit=unit)
    return None

# %%
df = DataFrame(columns=('sample name',
                        'lineage',
                        'biome',
                        'feature',
                        'material',
                        'package',
                        'latitude',
                        'longitude',
                        'depth',
                        'elevation',
                        'region',
                        'instrument model',
                        'investigation type',
                        'sequencing method',
                        'collection-date',
                        'forward reads',
                        'reverse reads',
                        'analyzes id',
                        'analyzes links'))
df.index.name = 'sample accession'

depth_label = 'geographic location (depth)'
latitude_label = 'geographic location (latitude)'
longitude_label = 'geographic location (longitude)'
region_label = 'geographic location (country and/or sea,region)'
date_label = 'collection date'
elevation_label = 'elevation'
env_biome_label = 'environment (biome)'
env_feature_label = 'environment (feature)'
env_material_label = 'environment (material)'
env_package_label = 'environmental package'
instrument_model_label = 'instrument model'
investigation_label = 'investigation type'
sequence_method_label = 'sequencing method'

with Session(MGNIFY_API_BASE) as mg:
    params = {
        'metadata_key': 'investigation type',
        'metadata_value': 'metagenome',
        'lineage': 'root:Environmental:Terrestrial',
        'include': 'runs'
    }
    fltr = Filter(urlencode(params))
    last_sample = 0
    #i = 0
    for sample in mg.iterate('samples', fltr):
            #if i > 20: break
            #i += 1
            last_sample = sample
        
            #try
            ena_params = {
                'accession': sample.accession,
                'result': 'read_run',
                'fields': 'fastq_ftp',
                'format': 'JSON'
            }
            try:
                data = json.loads(requests.get(ena_url, params=ena_params).text)
                fastq_links = ';'.join([d['fastq_ftp'] for d in data])
                fastq_links = fastq_links.split(';')
                forward_reads = ';'.join(list(filter(lambda s: s[-11:-9] != '_2', fastq_links)))
                reverse_reads = ';'.join(list(filter(lambda s: s[-11:-9] == '_2', fastq_links)))
            except Exception:
                forward_reads = None
                reverse_reads = None
            
            analyzes = []
            downloads = []
            for run in mg.iterate(f'samples/{sample.accession}/runs'):
                for an in mg.iterate(f'runs/{run.id}/analyses'):
                    analyzes.append(an.id)
                    for dnl in mg.iterate(f'analyses/{an.id}/downloads'):
                        downloads.append(str(dnl.links.self))
            analyzes = ';'.join(analyzes)
            downloads = ';'.join(downloads)
            
            df.loc[sample.accession] = [
                sample.sample_name,
                sample.biome.id,
                get_metadata(sample.sample_metadata, env_biome_label),
                get_metadata(sample.sample_metadata, env_feature_label),
                get_metadata(sample.sample_metadata, env_material_label),
                get_metadata(sample.sample_metadata, env_package_label),
                get_metadata(sample.sample_metadata, latitude_label),
                get_metadata(sample.sample_metadata, longitude_label),
                get_metadata(sample.sample_metadata, depth_label),
                get_metadata(sample.sample_metadata, elevation_label),
                get_metadata(sample.sample_metadata, region_label),
                get_metadata(sample.sample_metadata, instrument_model_label),
                get_metadata(sample.sample_metadata, investigation_label),
                get_metadata(sample.sample_metadata, sequence_method_label),
                get_metadata(sample.sample_metadata, date_label),
                forward_reads,
                reverse_reads,
                analyzes,
                downloads
            ]
        #except Exception:
           # print(sample.accession)
            #continue

df.to_csv('diploma_samples_terresrial')

df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# C:\Users\DARYA~1.MIZ\AppData\Local\Temp/ipykernel_9760/3868907505.py in <module>
#      56             }
#      57
# ---> 58             data = json.loads(requests.get(ena_url, params=ena_params).text)
#      59             fastq_links = ';'.join([d['fastq_ftp'] for d in data])
#      60             fastq_links = fastq_links.split(';')
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df
# Out:
#                       sample name  \
# sample accession
# ERS3341288          SK-16S-01_S21
# ERS3341289          SK-16S-02_S22
# ERS3341290          SK-16S-03_S23
# ERS3341291          SK-16S-04_S24
# ERS3341292          SK-16S-05_S25
# ...                           ...
# ERS1456720        Greenland Soils
# ERS1456721        Greenland Soils
# ERS1456722        Greenland Soils
# ERS1456723        Greenland Soils
# ERS1456724        Greenland Soils
#
#                                                             lineage  biome  \
# sample accession
# ERS3341288                      root:Environmental:Terrestrial:Soil  arid
# ERS3341289                      root:Environmental:Terrestrial:Soil  arid
# ERS3341290                      root:Environmental:Terrestrial:Soil  arid
# ERS3341291                      root:Environmental:Terrestrial:Soil  arid
# ERS3341292                      root:Environmental:Terrestrial:Soil  arid
# ...                                                             ...    ...
# ERS1456720        root:Environmental:Terrestrial:Soil:Oil-contam...   None
# ERS1456721        root:Environmental:Terrestrial:Soil:Oil-contam...   None
# ERS1456722        root:Environmental:Terrestrial:Soil:Oil-contam...   None
# ERS1456723        root:Environmental:Terrestrial:Soil:Oil-contam...   None
# ERS1456724        root:Environmental:Terrestrial:Soil:Oil-contam...   None
#
#                         feature material package latitude longitude depth  \
# sample accession
# ERS3341288        agricultural     soil    soil   -26.73     25.99   None
# ERS3341289        agricultural     soil    soil   -26.73     25.99   None
# ERS3341290        agricultural     soil    soil   -26.73     25.99   None
# ERS3341291        agricultural     soil    soil   -26.73     25.99   None
# ERS3341292        agricultural     soil    soil   -26.73     25.99   None
# ...                         ...      ...     ...      ...       ...   ...
# ERS1456720                 None     None    None     None      None   1 m
# ERS1456721                 None     None    None     None      None   1 m
# ERS1456722                 None     None    None     None      None   1 m
# ERS1456723                 None     None    None     None      None   1 m
# ERS1456724                 None     None    None     None      None   1 m
#
#                  elevation         region instrument model investigation type  \
# sample accession
# ERS3341288         1479.0   South Africa              None        metagenome
# ERS3341289         1479.0   South Africa              None        metagenome
# ERS3341290         1479.0   South Africa              None        metagenome
# ERS3341291         1479.0   South Africa              None        metagenome
# ERS3341292         1479.0   South Africa              None        metagenome
# ...                    ...            ...              ...                ...
# ERS1456720            None           None  Illumina MiSeq         metagenome
# ERS1456721            None           None  Illumina MiSeq         metagenome
# ERS1456722            None           None  Illumina MiSeq         metagenome
# ERS1456723            None           None  Illumina MiSeq         metagenome
# ERS1456724            None           None  Illumina MiSeq         metagenome
#
#                     sequencing method collection-date  \
# sample accession
# ERS3341288        Illumina Miseq 16S      2017-02-01
# ERS3341289        Illumina Miseq 16S      2017-02-01
# ERS3341290        Illumina Miseq 16S      2017-02-01
# ERS3341291        Illumina Miseq 16S      2017-02-01
# ERS3341292        Illumina Miseq 16S      2017-02-01
# ...                               ...             ...
# ERS1456720            Illumina Miseq         2010-01
# ERS1456721            Illumina Miseq         2010-01
# ERS1456722            Illumina Miseq         2010-01
# ERS1456723            Illumina Miseq         2010-01
# ERS1456724            Illumina Miseq         2010-01
#
#                                                       forward reads  \
# sample accession
# ERS3341288        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/006/ERR325...
# ERS3341289        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/007/ERR325...
# ERS3341290        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/008/ERR325...
# ERS3341291        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/009/ERR325...
# ERS3341292        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/000/ERR325...
# ...                                                             ...
# ERS1456720        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/004/ERR174...
# ERS1456721        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/005/ERR174...
# ERS1456722        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/006/ERR174...
# ERS1456723        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/007/ERR174...
# ERS1456724        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/008/ERR174...
#
#                                                       reverse reads  \
# sample accession
# ERS3341288        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/006/ERR325...
# ERS3341289        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/007/ERR325...
# ERS3341290        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/008/ERR325...
# ERS3341291        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/009/ERR325...
# ERS3341292        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/000/ERR325...
# ...                                                             ...
# ERS1456720        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/004/ERR174...
# ERS1456721        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/005/ERR174...
# ERS1456722        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/006/ERR174...
# ERS1456723        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/007/ERR174...
# ERS1456724        ftp.sra.ebi.ac.uk/vol1/fastq/ERR174/008/ERR174...
#
#                                              analyzes id  \
# sample accession
# ERS3341288        MGYA00594700;MGYA00594735;MGYA00594774
# ERS3341289        MGYA00594699;MGYA00594734;MGYA00594773
# ERS3341290        MGYA00594698;MGYA00594733;MGYA00594772
# ERS3341291                     MGYA00594732;MGYA00594771
# ERS3341292        MGYA00594697;MGYA00594731;MGYA00594770
# ...                                                  ...
# ERS1456720                                  MGYA00086983
# ERS1456721                                  MGYA00087066
# ERS1456722                                  MGYA00087070
# ERS1456723                                  MGYA00087027
# ERS1456724                                  MGYA00087037
#
#                                                      analyzes links
# sample accession
# ERS3341288        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS3341289        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS3341290        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS3341291        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS3341292        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ...                                                             ...
# ERS1456720        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS1456721        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS1456722        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS1456723        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS1456724        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
#
# [4119 rows x 19 columns]

# %%
df.to_csv('diploma_samples_terresrial_reserve')

# %%
last_sample.accession
# Out:
# 'ERS1456725'

# %%
flag = 0
for sample in mg.iterate('samples', fltr):
            #if i > 20: break
            #i += 1
    if sample.accession == last_sample.accession:
        flag = 1
        print('I am here')
        
    if flag != 0:
            last_sample = sample
            #try
            ena_params = {
                'accession': sample.accession,
                'result': 'read_run',
                'fields': 'fastq_ftp',
                'format': 'JSON'
            }
            try:
                data = json.loads(requests.get(ena_url, params=ena_params).text)
                fastq_links = ';'.join([d['fastq_ftp'] for d in data])
                fastq_links = fastq_links.split(';')
                forward_reads = ';'.join(list(filter(lambda s: s[-11:-9] != '_2', fastq_links)))
                reverse_reads = ';'.join(list(filter(lambda s: s[-11:-9] == '_2', fastq_links)))
            except Exception:
                forward_reads = None
                reverse_reads = None
            
            analyzes = []
            downloads = []
            for run in mg.iterate(f'samples/{sample.accession}/runs'):
                for an in mg.iterate(f'runs/{run.id}/analyses'):
                    analyzes.append(an.id)
                    for dnl in mg.iterate(f'analyses/{an.id}/downloads'):
                        downloads.append(str(dnl.links.self))
            analyzes = ';'.join(analyzes)
            downloads = ';'.join(downloads)
            
            df.loc[sample.accession] = [
                sample.sample_name,
                sample.biome.id,
                get_metadata(sample.sample_metadata, env_biome_label),
                get_metadata(sample.sample_metadata, env_feature_label),
                get_metadata(sample.sample_metadata, env_material_label),
                get_metadata(sample.sample_metadata, env_package_label),
                get_metadata(sample.sample_metadata, latitude_label),
                get_metadata(sample.sample_metadata, longitude_label),
                get_metadata(sample.sample_metadata, depth_label),
                get_metadata(sample.sample_metadata, elevation_label),
                get_metadata(sample.sample_metadata, region_label),
                get_metadata(sample.sample_metadata, instrument_model_label),
                get_metadata(sample.sample_metadata, investigation_label),
                get_metadata(sample.sample_metadata, sequence_method_label),
                get_metadata(sample.sample_metadata, date_label),
                forward_reads,
                reverse_reads,
                analyzes,
                downloads
            ]
        #except Exception:
           # print(sample.accession)
            #continue
    else:
        continue

df.to_csv('diploma_samples_terresrial')

df
# Out:
# I am here
#                     sample name  \
# sample accession
# ERS3341288        SK-16S-01_S21
# ERS3341289        SK-16S-02_S22
# ERS3341290        SK-16S-03_S23
# ERS3341291        SK-16S-04_S24
# ERS3341292        SK-16S-05_S25
# ...                         ...
# ERS227009                2400m3
# ERS227010                3000m1
# ERS227011                3000m2
# ERS227012                3000m3
# ERS421813             tibet.RL1
#
#                                                             lineage  biome  \
# sample accession
# ERS3341288                      root:Environmental:Terrestrial:Soil  arid
# ERS3341289                      root:Environmental:Terrestrial:Soil  arid
# ERS3341290                      root:Environmental:Terrestrial:Soil  arid
# ERS3341291                      root:Environmental:Terrestrial:Soil  arid
# ERS3341292                      root:Environmental:Terrestrial:Soil  arid
# ...                                                             ...    ...
# ERS227009         root:Environmental:Terrestrial:Soil:Tropical r...   None
# ERS227010         root:Environmental:Terrestrial:Soil:Tropical r...   None
# ERS227011         root:Environmental:Terrestrial:Soil:Tropical r...   None
# ERS227012         root:Environmental:Terrestrial:Soil:Tropical r...   None
# ERS421813                       root:Environmental:Terrestrial:Soil   None
#
#                         feature material package latitude longitude depth  \
# sample accession
# ERS3341288        agricultural     soil    soil   -26.73     25.99   None
# ERS3341289        agricultural     soil    soil   -26.73     25.99   None
# ERS3341290        agricultural     soil    soil   -26.73     25.99   None
# ERS3341291        agricultural     soil    soil   -26.73     25.99   None
# ERS3341292        agricultural     soil    soil   -26.73     25.99   None
# ...                         ...      ...     ...      ...       ...   ...
# ERS227009                  None     None   soil      None      None  .1 m
# ERS227010                  None     None   soil      None      None  .1 m
# ERS227011                  None     None   soil      None      None  .1 m
# ERS227012                  None     None   soil      None      None  .1 m
# ERS421813                  None     None    None     None      None  None
#
#                  elevation         region      instrument model  \
# sample accession
# ERS3341288         1479.0   South Africa                   None
# ERS3341289         1479.0   South Africa                   None
# ERS3341290         1479.0   South Africa                   None
# ERS3341291         1479.0   South Africa                   None
# ERS3341292         1479.0   South Africa                   None
# ...                    ...            ...                   ...
# ERS227009             None           None  454 GS FLX Titanium
# ERS227010             None           None  454 GS FLX Titanium
# ERS227011             None           None  454 GS FLX Titanium
# ERS227012             None           None  454 GS FLX Titanium
# ERS421813             None           None  454 GS FLX Titanium
#
#                  investigation type           sequencing method  \
# sample accession
# ERS3341288              metagenome          Illumina Miseq 16S
# ERS3341289              metagenome          Illumina Miseq 16S
# ERS3341290              metagenome          Illumina Miseq 16S
# ERS3341291              metagenome          Illumina Miseq 16S
# ERS3341292              metagenome          Illumina Miseq 16S
# ...                             ...                         ...
# ERS227009               metagenome   Roche 454 GS FLX Titanium
# ERS227010               metagenome   Roche 454 GS FLX Titanium
# ERS227011               metagenome   Roche 454 GS FLX Titanium
# ERS227012               metagenome   Roche 454 GS FLX Titanium
# ERS421813               metagenome              454 sequencing
#
#                  collection-date  \
# sample accession
# ERS3341288           2017-02-01
# ERS3341289           2017-02-01
# ERS3341290           2017-02-01
# ERS3341291           2017-02-01
# ERS3341292           2017-02-01
# ...                          ...
# ERS227009               2010-10
# ERS227010               2010-10
# ERS227011               2010-10
# ERS227012               2010-10
# ERS421813                   None
#
#                                                       forward reads  \
# sample accession
# ERS3341288        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/006/ERR325...
# ERS3341289        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/007/ERR325...
# ERS3341290        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/008/ERR325...
# ERS3341291        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/009/ERR325...
# ERS3341292        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/000/ERR325...
# ...                                                             ...
# ERS227009         ftp.sra.ebi.ac.uk/vol1/fastq/ERR249/ERR249387/...
# ERS227010         ftp.sra.ebi.ac.uk/vol1/fastq/ERR249/ERR249388/...
# ERS227011         ftp.sra.ebi.ac.uk/vol1/fastq/ERR249/ERR249389/...
# ERS227012         ftp.sra.ebi.ac.uk/vol1/fastq/ERR249/ERR249390/...
# ERS421813         ftp.sra.ebi.ac.uk/vol1/fastq/ERR458/ERR458084/...
#
#                                                       reverse reads  \
# sample accession
# ERS3341288        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/006/ERR325...
# ERS3341289        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/007/ERR325...
# ERS3341290        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/008/ERR325...
# ERS3341291        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/009/ERR325...
# ERS3341292        ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/000/ERR325...
# ...                                                             ...
# ERS227009
# ERS227010
# ERS227011
# ERS227012
# ERS421813
#
#                                              analyzes id  \
# sample accession
# ERS3341288        MGYA00594700;MGYA00594735;MGYA00594774
# ERS3341289        MGYA00594699;MGYA00594734;MGYA00594773
# ERS3341290        MGYA00594698;MGYA00594733;MGYA00594772
# ERS3341291                     MGYA00594732;MGYA00594771
# ERS3341292        MGYA00594697;MGYA00594731;MGYA00594770
# ...                                                  ...
# ERS227009                                   MGYA00000692
# ERS227010                                   MGYA00000693
# ERS227011                                   MGYA00000694
# ERS227012                                   MGYA00000695
# ERS421813                                   MGYA00002226
#
#                                                      analyzes links
# sample accession
# ERS3341288        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS3341289        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS3341290        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS3341291        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS3341292        https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ...                                                             ...
# ERS227009         https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS227010         https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS227011         https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS227012         https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ERS421813         https://www.ebi.ac.uk/metagenomics/api/v1/anal...
#
# [6452 rows x 19 columns]

# %%
df2 = read_csv('diploma_samples_terresrial')
df2
# Out:
#      sample accession    sample name  \
# 0          ERS3341288  SK-16S-01_S21
# 1          ERS3341289  SK-16S-02_S22
# 2          ERS3341290  SK-16S-03_S23
# 3          ERS3341291  SK-16S-04_S24
# 4          ERS3341292  SK-16S-05_S25
# ...               ...            ...
# 6447        ERS227009         2400m3
# 6448        ERS227010         3000m1
# 6449        ERS227011         3000m2
# 6450        ERS227012         3000m3
# 6451        ERS421813      tibet.RL1
#
#                                                 lineage  biome        feature  \
# 0                   root:Environmental:Terrestrial:Soil  arid   agricultural
# 1                   root:Environmental:Terrestrial:Soil  arid   agricultural
# 2                   root:Environmental:Terrestrial:Soil  arid   agricultural
# 3                   root:Environmental:Terrestrial:Soil  arid   agricultural
# 4                   root:Environmental:Terrestrial:Soil  arid   agricultural
# ...                                                 ...    ...            ...
# 6447  root:Environmental:Terrestrial:Soil:Tropical r...    NaN            NaN
# 6448  root:Environmental:Terrestrial:Soil:Tropical r...    NaN            NaN
# 6449  root:Environmental:Terrestrial:Soil:Tropical r...    NaN            NaN
# 6450  root:Environmental:Terrestrial:Soil:Tropical r...    NaN            NaN
# 6451                root:Environmental:Terrestrial:Soil    NaN            NaN
#
#      material package latitude longitude depth elevation         region  \
# 0       soil    soil   -26.73     25.99    NaN   1479.0   South Africa
# 1       soil    soil   -26.73     25.99    NaN   1479.0   South Africa
# 2       soil    soil   -26.73     25.99    NaN   1479.0   South Africa
# 3       soil    soil   -26.73     25.99    NaN   1479.0   South Africa
# 4       soil    soil   -26.73     25.99    NaN   1479.0   South Africa
# ...       ...     ...      ...       ...   ...       ...            ...
# 6447      NaN   soil       NaN       NaN  .1 m       NaN            NaN
# 6448      NaN   soil       NaN       NaN  .1 m       NaN            NaN
# 6449      NaN   soil       NaN       NaN  .1 m       NaN            NaN
# 6450      NaN   soil       NaN       NaN  .1 m       NaN            NaN
# 6451      NaN     NaN      NaN       NaN   NaN       NaN            NaN
#
#           instrument model investigation type           sequencing method  \
# 0                      NaN        metagenome          Illumina Miseq 16S
# 1                      NaN        metagenome          Illumina Miseq 16S
# 2                      NaN        metagenome          Illumina Miseq 16S
# 3                      NaN        metagenome          Illumina Miseq 16S
# 4                      NaN        metagenome          Illumina Miseq 16S
# ...                    ...                ...                         ...
# 6447  454 GS FLX Titanium         metagenome   Roche 454 GS FLX Titanium
# 6448  454 GS FLX Titanium         metagenome   Roche 454 GS FLX Titanium
# 6449  454 GS FLX Titanium         metagenome   Roche 454 GS FLX Titanium
# 6450  454 GS FLX Titanium         metagenome   Roche 454 GS FLX Titanium
# 6451  454 GS FLX Titanium         metagenome              454 sequencing
#
#      collection-date                                      forward reads  \
# 0        2017-02-01   ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/006/ERR325...
# 1        2017-02-01   ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/007/ERR325...
# 2        2017-02-01   ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/008/ERR325...
# 3        2017-02-01   ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/009/ERR325...
# 4        2017-02-01   ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/000/ERR325...
# ...              ...                                                ...
# 6447        2010-10   ftp.sra.ebi.ac.uk/vol1/fastq/ERR249/ERR249387/...
# 6448        2010-10   ftp.sra.ebi.ac.uk/vol1/fastq/ERR249/ERR249388/...
# 6449        2010-10   ftp.sra.ebi.ac.uk/vol1/fastq/ERR249/ERR249389/...
# 6450        2010-10   ftp.sra.ebi.ac.uk/vol1/fastq/ERR249/ERR249390/...
# 6451             NaN  ftp.sra.ebi.ac.uk/vol1/fastq/ERR458/ERR458084/...
#
#                                           reverse reads  \
# 0     ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/006/ERR325...
# 1     ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/007/ERR325...
# 2     ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/008/ERR325...
# 3     ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/009/ERR325...
# 4     ftp.sra.ebi.ac.uk/vol1/fastq/ERR325/000/ERR325...
# ...                                                 ...
# 6447                                                NaN
# 6448                                                NaN
# 6449                                                NaN
# 6450                                                NaN
# 6451                                                NaN
#
#                                  analyzes id  \
# 0     MGYA00594700;MGYA00594735;MGYA00594774
# 1     MGYA00594699;MGYA00594734;MGYA00594773
# 2     MGYA00594698;MGYA00594733;MGYA00594772
# 3                  MGYA00594732;MGYA00594771
# 4     MGYA00594697;MGYA00594731;MGYA00594770
# ...                                      ...
# 6447                            MGYA00000692
# 6448                            MGYA00000693
# 6449                            MGYA00000694
# 6450                            MGYA00000695
# 6451                            MGYA00002226
#
#                                          analyzes links
# 0     https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 1     https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 2     https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 3     https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 4     https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ...                                                 ...
# 6447  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 6448  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 6449  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 6450  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 6451  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
#
# [6452 rows x 20 columns]
